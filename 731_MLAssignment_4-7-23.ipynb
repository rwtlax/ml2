# %% [markdown]
# # Aquisition of data

# %%
# Aquisition of data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Import the data

# %%
# import the data
df=pd.read_csv('fundamentals.csv')
df.head()
# Out:
#    Unnamed: 0 Ticker Symbol Period Ending  Accounts Payable  \
# 0           0           AAL    2012-12-31      3.068000e+09
# 1           1           AAL    2013-12-31      4.975000e+09
# 2           2           AAL    2014-12-31      4.668000e+09
# 3           3           AAL    2015-12-31      5.102000e+09
# 4           4           AAP    2012-12-29      2.409453e+09
#
#    Accounts Receivable  Add'l income/expense items  After Tax ROE  \
# 0         -222000000.0               -1.961000e+09           23.0
# 1          -93000000.0               -2.723000e+09           67.0
# 2         -160000000.0               -1.500000e+08          143.0
# 3          352000000.0               -7.080000e+08          135.0
# 4          -89482000.0                6.000000e+05           32.0
#
#    Capital Expenditures  Capital Surplus  Cash Ratio  ...  \
# 0         -1.888000e+09     4.695000e+09        53.0  ...
# 1         -3.114000e+09     1.059200e+10        75.0  ...
# ...

# %% [markdown]
# # Perform EDA

# %%
df.info() # Perform EDA
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1781 entries, 0 to 1780
# Data columns (total 79 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Unnamed: 0                                           1781 non-null   int64
#  1   Ticker Symbol                                        1781 non-null   object
#  2   Period Ending                                        1781 non-null   object
#  3   Accounts Payable                                     1781 non-null   float64
#  4   Accounts Receivable                                  1781 non-null   float64
#  5   Add'l income/expense items                           1781 non-null   float64
#  6   After Tax ROE                                        1781 non-null   float64
#  7   Capital Expenditures                                 1781 non-null   float64
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0  Accounts Payable  Accounts Receivable  \
# count  1781.000000      1.781000e+03         1.781000e+03
# mean    890.000000      4.673418e+09        -6.353484e+07
# std     514.274732      1.406047e+10         7.562794e+08
# min       0.000000      0.000000e+00        -6.452000e+09
# 25%     445.000000      5.160000e+08        -1.040000e+08
# 50%     890.000000      1.334000e+09        -1.830000e+07
# 75%    1335.000000      3.246000e+09         7.816000e+06
# max    1780.000000      2.069390e+11         2.266400e+10
#
#        Add'l income/expense items  After Tax ROE  Capital Expenditures  \
# count                1.781000e+03    1781.000000          1.781000e+03
# mean                 6.908940e+07      43.601348         -1.251925e+09
# std                  6.848143e+08     233.924028          2.979963e+09
# min                 -6.768000e+09       0.000000         -3.798500e+10
# 25%                 -2.638000e+06      10.000000         -1.151200e+09
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                               Unnamed: 0  Accounts Payable  \
# Unnamed: 0                      1.000000         -0.040855
# Accounts Payable               -0.040855          1.000000
# Accounts Receivable             0.030659          0.081415
# Add'l income/expense items      0.057706          0.147322
# After Tax ROE                  -0.005466         -0.017927
# ...                                  ...               ...
# Total Revenue                   0.024759          0.542084
# Treasury Stock                 -0.049339         -0.233946
# For Year                        0.001792         -0.005447
# Earnings Per Share             -0.018553          0.068627
# Estimated Shares Outstanding   -0.008534          0.606004
#
#                               Accounts Receivable  Add'l income/expense items  \
# Unnamed: 0                               0.030659                    0.057706
# Accounts Payable                         0.081415                    0.147322
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                        0
# Ticker Symbol                     0
# Period Ending                     0
# Accounts Payable                  0
# Accounts Receivable               0
#                                ...
# Total Revenue                     0
# Treasury Stock                    0
# For Year                        173
# Earnings Per Share              219
# Estimated Shares Outstanding    219
# Length: 79, dtype: int64

# %%
df.isnull().mean()*100 # There is no such column which has 75% null values
# Out:
# Unnamed: 0                       0.000000
# Ticker Symbol                    0.000000
# Period Ending                    0.000000
# Accounts Payable                 0.000000
# Accounts Receivable              0.000000
#                                   ...
# Total Revenue                    0.000000
# Treasury Stock                   0.000000
# For Year                         9.713644
# Earnings Per Share              12.296463
# Estimated Shares Outstanding    12.296463
# Length: 79, dtype: float64

# %%
# Replace the null values as 0.00
# df.replace(np.nan, 0.00, inplace=True)

# %%
new_df=df.columns[df.isna().any()].tolist()
new_df1=df[new_df].copy()
new_df1.fillna(0.00, inplace=True)
new_df1.sample(5)
# Out:
#       Cash Ratio  Current Ratio  Quick Ratio  For Year  Earnings Per Share  \
# 310          1.0           22.0         22.0    2013.0               -1.65
# 1446        12.0           87.0         77.0    2012.0                3.56
# 1735         2.0           83.0         68.0    2014.0                2.03
# 1399        17.0          152.0        112.0    2014.0                1.22
# 553         46.0          142.0        123.0    2013.0                8.13
#
#       Estimated Shares Outstanding
# 310                   1.024242e+08
# 1446                  2.429775e+08
# 1735                  5.031064e+08
# 1399                  1.275410e+08
# 553                   2.702471e+08

# %%
cl_df=df.copy().drop(new_df1,axis=1)
cl_df.head()
# Out:
#    Unnamed: 0 Ticker Symbol Period Ending  Accounts Payable  \
# 0           0           AAL    2012-12-31      3.068000e+09
# 1           1           AAL    2013-12-31      4.975000e+09
# 2           2           AAL    2014-12-31      4.668000e+09
# 3           3           AAL    2015-12-31      5.102000e+09
# 4           4           AAP    2012-12-29      2.409453e+09
#
#    Accounts Receivable  Add'l income/expense items  After Tax ROE  \
# 0         -222000000.0               -1.961000e+09           23.0
# 1          -93000000.0               -2.723000e+09           67.0
# 2         -160000000.0               -1.500000e+08          143.0
# 3          352000000.0               -7.080000e+08          135.0
# 4          -89482000.0                6.000000e+05           32.0
#
#    Capital Expenditures  Capital Surplus  Cash and Cash Equivalents  ...  \
# 0         -1.888000e+09     4.695000e+09               1.330000e+09  ...
# ...

# %%
mean1=new_df1.mean(numeric_only=True)
df4=new_df1.replace(0.00, mean1)
df4.head()
# Out:
#    Cash Ratio  Current Ratio  Quick Ratio  For Year  Earnings Per Share  \
# 0        53.0           78.0         72.0    2012.0               -5.60
# 1        75.0          104.0         96.0    2013.0              -11.25
# 2        60.0           88.0         80.0    2014.0                4.02
# 3        51.0           73.0         67.0    2015.0               11.39
# 4        23.0          124.0         34.0    2012.0                5.29
#
#    Estimated Shares Outstanding
# 0                  3.350000e+08
# 1                  1.630222e+08
# 2                  7.169154e+08
# 3                  6.681299e+08
# 4                  7.328355e+07

# %%
median1=new_df1.median(numeric_only=True)
df5=new_df1.replace(0.00, median1)

# %%
mode1=new_df1.mode(numeric_only=True)
mode1
# Out:
#    Cash Ratio  Current Ratio  Quick Ratio  For Year  Earnings Per Share  \
# 0         0.0            0.0          0.0    2014.0                 0.0
#
#    Estimated Shares Outstanding
# 0                           0.0

# %%
sns.displot(new_df1['Cash Ratio']) # Before Replacing
sns.displot(df4['Cash Ratio']) # After Repalcing with Mean
sns.displot(df5['Cash Ratio']) # After Repalcing with Median

# %%
plt.plot(new_df1, color='red') # Before Repalcing
plt.plot(df4, color='blue') # After Repalcing with Mean
plt.plot(df5, color='yellow') # After Repalcing with Median
plt.show()

# %%
# Check the co-linerarity of every column
corr_matrix = df.corr(numeric_only=True)
sns.heatmap(corr_matrix)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    Unnamed: 0 Ticker Symbol Period Ending  Accounts Payable  \
# 0           0           AAL    2012-12-31      3.068000e+09
# 1           1           AAL    2013-12-31      4.975000e+09
# 2           2           AAL    2014-12-31      4.668000e+09
# 3           3           AAL    2015-12-31      5.102000e+09
# 4           4           AAP    2012-12-29      2.409453e+09
#
#    Accounts Receivable  Add'l income/expense items  After Tax ROE  \
# 0         -222000000.0               -1.961000e+09           23.0
# 1          -93000000.0               -2.723000e+09           67.0
# 2         -160000000.0               -1.500000e+08          143.0
# 3          352000000.0               -7.080000e+08          135.0
# 4          -89482000.0                6.000000e+05           32.0
#
#    Capital Expenditures  Capital Surplus  Cash Ratio  ...  \
# 0         -1.888000e+09     4.695000e+09        53.0  ...
# 1         -3.114000e+09     1.059200e+10        75.0  ...
# ...

# %%
df3=df.corr(numeric_only=True)['Total Revenue']
df3[df3>0.7].index.tolist()
# Out:
# ['Cost of Revenue',
#  'Earnings Before Interest and Tax',
#  'Earnings Before Tax',
#  'Gross Profit',
#  'Income Tax',
#  'Net Income-Cont. Operations',
#  'Sales, General and Admin.',
#  'Total Current Liabilities',
#  'Total Revenue']

# %%
x = df[['Cost of Revenue',
 'Earnings Before Interest and Tax',
 'Earnings Before Tax',
 'Gross Profit',
 'Income Tax',
 'Net Income-Cont. Operations',
 'Sales, General and Admin.',
 'Total Current Liabilities'
 ]]
x
# Out:
#       Cost of Revenue  Earnings Before Interest and Tax  Earnings Before Tax  \
# 0        1.049900e+10                     -1.813000e+09        -2.445000e+09
# 1        1.101900e+10                     -1.324000e+09        -2.180000e+09
# 2        1.562000e+10                      4.099000e+09         3.212000e+09
# 3        1.109600e+10                      5.496000e+09         4.616000e+09
# 4        3.106967e+09                      6.579150e+08         6.240740e+08
# ...               ...                               ...                  ...
# 1776     4.934400e+07                      5.207260e+08         4.518590e+08
# 1777     1.669000e+09                      8.030000e+08         6.900000e+08
# 1778     1.717000e+09                      9.370000e+08         8.200000e+08
# 1779     1.738000e+09                      6.690000e+08         5.450000e+08
# 1780     1.666000e+09                      1.394000e+09         1.228000e+09
#
# ...

# %%
y=df[['Total Revenue']]
y
# Out:
#       Total Revenue
# 0      2.485500e+10
# 1      2.674300e+10
# 2      4.265000e+10
# 3      4.099000e+10
# 4      6.205003e+09
# ...             ...
# 1776   2.210591e+09
# 1777   4.561000e+09
# 1778   4.785000e+09
# 1779   4.765000e+09
# 1780   4.888000e+09
#
# [1781 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import Lasso

# %%
alphas = [0.001,0.01,0.1,1,2,3,4,5,6,15,20,30,50,100]
for i in alphas:
    l=Lasso(alpha=i)
    l.fit(x_train,y_train)
    print(l.coef_) # beta ki values
# Out:
# [ 1.00527935  0.97206639  0.39699     0.34732428 -0.41577661 -0.71749127
#   0.70269407 -0.01165278]
# [ 1.00527935  0.97206639  0.39699     0.34732428 -0.41577661 -0.71749127
#   0.70269407 -0.01165278]
# [ 1.00527935  0.97206639  0.39699     0.34732428 -0.41577661 -0.71749127
#   0.70269407 -0.01165278]
# [ 1.00527935  0.97206639  0.39699     0.34732428 -0.41577661 -0.71749127
#   0.70269407 -0.01165278]
# [ 1.00527935  0.97206639  0.39699     0.34732428 -0.41577661 -0.71749127
#   0.70269407 -0.01165278]
# [ 1.00527935  0.97206639  0.39699     0.34732428 -0.41577661 -0.71749127
#   0.70269407 -0.01165278]
# [ 1.00527935  0.97206639  0.39699     0.34732428 -0.41577661 -0.71749127
#   0.70269407 -0.01165278]
# [ 1.00527935  0.97206639  0.39699     0.34732428 -0.41577661 -0.71749127
#   0.70269407 -0.01165278]
# [ 1.00527935  0.97206639  0.39699     0.34732428 -0.41577661 -0.71749127
#   0.70269407 -0.01165278]
# ...

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import r2_score, mean_squared_error
from math import sqrt

# Create and fit the Lasso regression model
lasso_model = Lasso(alpha=0.1)  # Adjust the alpha value
lasso_model.fit(x_train, y_train)

# Predict using the Lasso model
y_pred = lasso_model.predict(x_test)

# Calculate R-squared
r2 = r2_score(y_test, y_pred)
print('R-squared:', r2)
# Out:
# R-squared: 0.9923197335604832

# %%
r2
# Out:
# 0.9923197335604832
